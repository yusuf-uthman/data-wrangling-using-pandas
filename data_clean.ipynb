# %% [markdown]
# ## Data cleaning With Pandas

# %%
## Import necessary libraries
import pandas as pd
import numpy
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'billboard.csv',
#  'country_timeseries.csv',
#  'data_clean.ipynb',
#  'gapminder.tsv',
#  'pew.csv',
#  'README.md',
#  'weather.csv']

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
#Load pew Data
pew = pd.read_csv("pew.csv")

# %% [markdown]
# ## used the head() funtion to reduce data to the first few rows

# %%
pew.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
pew.shape
# Out:
# (18, 11)

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
# religion              18 non-null object
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 1.6+ KB

# %%
pew.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
pew_melt = pd.melt( pew,
                    id_vars = "religion",
                    var_name = "salary",
                    value_name = "count"
                    )

# %%
pew_melt.head()
# Out:
#              religion salary  count
# 0            Agnostic  <$10k     27
# 1             Atheist  <$10k     12
# 2            Buddhist  <$10k     27
# 3            Catholic  <$10k    418
# 4  Don’t know/refused  <$10k     15

# %%
pew.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
pew_long.columns
# Out:
# Index(['religion', 'salary', 'count'], dtype='object')

# %%
pew.shape
# Out:
# (18, 11)

# %%
pew_melt.shape
# Out:
# (180, 3)

# %% [markdown]
# ## Load Gapminder Data

# %%
gap = pd.read_csv("gapminder.tsv",sep = "\t")

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#To Get The Number of Rows and Columns in your dataset
gap.shape
# Out:
# (1704, 6)

# %%
#addtional infrmation about the dataset, showing the data types and also indicates null values
gap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gap.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %%
type(gap.values)
# Out:
# numpy.ndarray

# %%
help(numpy.ndarray)
# Out:
# Help on class ndarray in module numpy:
#
# class ndarray(builtins.object)
#  |  ndarray(shape, dtype=float, buffer=None, offset=0,
#  |          strides=None, order=None)
#  |
#  |  An array object represents a multidimensional, homogeneous array
#  |  of fixed-size items.  An associated data-type object describes the
#  |  format of each element in the array (its byte-order, how many bytes it
#  |  occupies in memory, whether it is an integer, a floating point number,
#  |  or something else, etc.)
#  |
#  |  Arrays should be constructed using `array`, `zeros` or `empty` (refer
#  |  to the See Also section below).  The parameters given here refer to
#  |  a low-level method (`ndarray(...)`) for instantiating an array.
#  |
#  |  For more information, refer to the `numpy` module and examine the
#  |  methods and attributes of an array.
#  |
#  |  Parameters
#  |  ----------
#  |  (for the __new__ method; see Notes below)
#  |
#  |  shape : tuple of ints
# ...

# %%
subset= gap[["country","continent","year"]]

# %%
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
subset = gap.loc [ : ,["country","pop","year"]]

# %%
subset.head()
# Out:
#        country       pop  year
# 0  Afghanistan   8425333  1952
# 1  Afghanistan   9240934  1957
# 2  Afghanistan  10267083  1962
# 3  Afghanistan  11537966  1967
# 4  Afghanistan  13079460  1972

# %%
subset = gap.loc [ gap["year"] == 1957 ,["year","pop","gdpPercap"]]

# %%
subset.head()
# Out:
#     year       pop    gdpPercap
# 1   1957   9240934   820.853030
# 13  1957   1476505  1942.284244
# 25  1957  10270856  3013.976023
# 37  1957   4561361  3827.940465
# 49  1957  19610538  6856.856212

# %%
#selecting through rows from a dataset using multiple conditions
#This didn't work because the code didnt specify if any or both conditions has to be true   
subset = gap.loc [ (gap["year"] == 1957) (gap["pop"] > 1_200_000) ,["year","pop","gdpPercap"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-c34b07e0b0a0> in <module>
# ----> 1 subset = gap.loc [ (gap["year"] == 1957) (gap["pop"] > 1_200_000) ,["year","pop","gdpPercap"]]
#
# TypeError: 'Series' object is not callable

# %%
#selecting through rows from a dataset using multiple conditions
#  Use & if you want both conditions to be true
#  Use | (pipe character) if you want either of the conditions to be true
subset = gap.loc [ (gap["year"] == 1957) & (gap["pop"] > 4_200_000) ,["year","pop","gdpPercap"]]

# %%
subset
# Out:
#       year        pop     gdpPercap
# 1     1957    9240934    820.853030
# 25    1957   10270856   3013.976023
# 37    1957    4561361   3827.940465
# 49    1957   19610538   6856.856212
# 61    1957    9712569  10949.649590
# 73    1957    6965860   8842.598030
# 97    1957   51365468    661.637458
# 109   1957    8989111   9714.960623
# 169   1957   65551171   2487.365989
# 181   1957    7651254   3008.670727
# 193   1957    4713416    617.183465
# 217   1957    5322536    434.038336
# 229   1957    5359923   1313.048099
# 241   1957   17010154  12489.950060
# 277   1957    7048426   4315.622723
# 289   1957  637408000    575.987001
# 301   1957   14485993   2323.805581
# 325   1957   15577932    905.860230
# 385   1957    6640752   6092.174359
# 397   1957    9513758   8256.343918
# 409   1957    4487831  11099.659350
# 457   1957   25009741   1458.915272
# 505   1957   22815614    378.904163
# 517   1957    4324000   7545.415386
# 529   1957   44310863   8662.834898
# ...

# %%
billboard = pd.read_csv("billboard.csv")

# %%
billboard
# Out:
#      year                artist                    track  time date.entered  \
# 0    2000                 2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1    2000               2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2    2000          3 Doors Down               Kryptonite  3:53   2000-04-08
# 3    2000          3 Doors Down                    Loser  4:24   2000-10-21
# 4    2000              504 Boyz            Wobble Wobble  3:35   2000-04-15
# 5    2000                  98^0  Give Me Just One Nig...  3:24   2000-08-19
# 6    2000               A*Teens            Dancing Queen  3:44   2000-07-08
# 7    2000               Aaliyah            I Don't Wanna  4:15   2000-01-29
# 8    2000               Aaliyah                Try Again  4:03   2000-03-18
# 9    2000        Adams, Yolanda            Open My Heart  5:30   2000-08-26
# 10   2000         Adkins, Trace                     More  3:05   2000-04-29
# ...

# %%
billboard.shape
# Out:
# (317, 81)

# %%
billboard_melt = pd.melt ( billboard,
                           id_vars = ["year","artist","track","time","date.entered"],
                           var_name = "week",
                           value_name = "rating"
                         )

# %%
billboard_melt.head()
# Out:
#    year        artist                    track  time date.entered week  rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1    87.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1    91.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08  wk1    81.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21  wk1    76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1    57.0

# %%
billboard.shape
# Out:
# (317, 81)

# %%
billboard_melt.shape
# Out:
# (24092, 7)

# %% [markdown]
# ## Loading country_timeseries.csv data

# %%
ebola = pd.read_csv ("country_timeseries.csv")
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...
